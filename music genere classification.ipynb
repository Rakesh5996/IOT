# %%
import pandas as pd
import numpy as np

# %%
#Reading CSV File

df = pd.read_csv(r"C:\Users\new\Dropbox\My PC (LAPTOP-VOB8LHM1)\Downloads\data.csv")

# %%
df.head()
# Out:
#   class_name       tempo  beats  chroma_stft      rmse  spectral_centroid  \
# 0      blues  103.359375     50     0.380260  0.248262        2116.942959
# 1      blues   95.703125     44     0.306451  0.113475        1156.070496
# 2      blues  151.999081     75     0.253487  0.151571        1331.073970
# 3      blues  184.570312     91     0.269320  0.119072        1361.045467
# 4      blues  161.499023     74     0.391059  0.137728        1811.076084
#
#    spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  ...  \
# 0         1956.611056  4196.107960            0.127272  -26.929785  ...
# 1         1497.668176  2170.053545            0.058613 -233.860772  ...
# 2         1973.643437  2900.174130            0.042967 -221.802549  ...
# 3         1567.804596  2739.625101            0.069124 -207.208080  ...
# 4         2052.332563  3927.809582            0.075480 -145.434568  ...
#
#       mfcc12     mfcc13    mfcc14    mfcc15    mfcc16     mfcc17     mfcc18  \
# 0  14.336612 -13.821769  7.562789 -6.181372  0.330165  -6.829571   0.965922
# 1  -2.250578   3.959198  5.322555  0.812028 -1.107202  -4.556555  -2.436490
# 2 -13.037723 -12.652228 -1.821905 -7.260097 -6.660252 -14.682694 -11.719264
# 3  -0.613248   0.384877  2.605128 -5.188924 -9.527455  -9.244394  -2.848274
# 4   7.457218 -10.470444 -2.360483 -6.783623  2.671134  -4.760879  -0.949005
#
#       mfcc19     mfcc20  label
# 0  -7.570825   2.918987  blues
# 1   3.316913  -0.608485  blues
# 2 -11.025216 -13.387260  blues
# 3  -1.418707  -5.932607  blues
# 4   0.024832  -2.005315  blues
#
# [5 rows x 30 columns]

# %%
#dropping the column
df = df.drop(['beats'], axis=1)

# %%
#head
df.head()
# Out:
#   class_name       tempo  chroma_stft      rmse  spectral_centroid  \
# 0      blues  103.359375     0.380260  0.248262        2116.942959
# 1      blues   95.703125     0.306451  0.113475        1156.070496
# 2      blues  151.999081     0.253487  0.151571        1331.073970
# 3      blues  184.570312     0.269320  0.119072        1361.045467
# 4      blues  161.499023     0.391059  0.137728        1811.076084
#
#    spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0         1956.611056  4196.107960            0.127272  -26.929785
# 1         1497.668176  2170.053545            0.058613 -233.860772
# 2         1973.643437  2900.174130            0.042967 -221.802549
# 3         1567.804596  2739.625101            0.069124 -207.208080
# 4         2052.332563  3927.809582            0.075480 -145.434568
#
#         mfcc2  ...     mfcc12     mfcc13    mfcc14    mfcc15    mfcc16  \
# 0  107.334008  ...  14.336612 -13.821769  7.562789 -6.181372  0.330165
# 1  136.170239  ...  -2.250578   3.959198  5.322555  0.812028 -1.107202
# 2  110.843070  ... -13.037723 -12.652228 -1.821905 -7.260097 -6.660252
# 3  132.799175  ...  -0.613248   0.384877  2.605128 -5.188924 -9.527455
# 4  102.829023  ...   7.457218 -10.470444 -2.360483 -6.783623  2.671134
#
#       mfcc17     mfcc18     mfcc19     mfcc20  label
# 0  -6.829571   0.965922  -7.570825   2.918987  blues
# 1  -4.556555  -2.436490   3.316913  -0.608485  blues
# 2 -14.682694 -11.719264 -11.025216 -13.387260  blues
# 3  -9.244394  -2.848274  -1.418707  -5.932607  blues
# 4  -4.760879  -0.949005   0.024832  -2.005315  blues
#
# [5 rows x 29 columns]

# %%
df['class_name'].unique()
# Out:
# array(['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz',
#        'metal', 'pop', 'reggae', 'rock'], dtype=object)

# %%
df['class_name'] = df['class_name'].astype('category')
df['class_label'] = df['class_name'].cat.codes

# %%
lookup_genre_name = dict(zip(df.class_label.unique(), df.class_name.unique()))   
lookup_genre_name
# Out:
# {0: 'blues',
#  1: 'classical',
#  2: 'country',
#  3: 'disco',
#  4: 'hiphop',
#  5: 'jazz',
#  6: 'metal',
#  7: 'pop',
#  8: 'reggae',
#  9: 'rock'}

# %%
df['class_name'].unique()
# Out:
# [blues, classical, country, disco, hiphop, jazz, metal, pop, reggae, rock]
# Categories (10, object): [blues, classical, country, disco, ..., metal, pop, reggae, rock]

# %%
cols = list(df.columns)
cols.remove('label')
cols.remove('class_label')
cols.remove('class_name')
#df[cols]

# %%
#splitting data for training and testing

# %matplotlib notebook
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
X = df.iloc[:,1:28]
y = df['class_label']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=3)

# %%
#min-max normalisation

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
# we must apply the scaling to the test set that we computed for the training set
X_test_scaled = scaler.transform(X_test)

# %%
#Feature importance uisng Random forest

from sklearn.ensemble import RandomForestClassifier
# %matplotlib notebook
clf = RandomForestClassifier(random_state=0, n_jobs=-1).fit(X_train_scaled, y_train)
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
names = [X.columns.values[i] for i in indices]
plt.figure()
plt.title("Feature Importance")
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), names, rotation=90)
plt.show()
clf.score(X_test_scaled, y_test)
# Out:
# <img src="data:image/png;base64,..." width="638.9999809563166">
# 0.704

# %%
#Feature importance using Decision Tree

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0).fit(X_train_scaled, y_train)
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
names = [X.columns.values[i] for i in indices]
plt.figure()
plt.title("Feature Importance")
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), names, rotation=90)
plt.show()
clf.score(X_test_scaled, y_test)
# Out:
# <img src="data:image/png;base64,..." width="638.9999809563166">
# 0.444

# %%
#K Nearest Neighbours

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 13)
knn.fit(X_train_scaled, y_train)
knn.score(X_test_scaled, y_test)
# Out:
# 0.624

# %%
pip install librosa
# Out:
# Collecting librosa
# Note: you may need to restart the kernel to use updated packages.  Downloading librosa-0.8.1-py3-none-any.whl (203 kB)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\new\anaconda3\lib\site-packages (from librosa) (0.23.1)
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-win_amd64.whl (689 kB)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\new\anaconda3\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\new\anaconda3\lib\site-packages (from librosa) (1.5.0)
# Requirement already satisfied: numba>=0.43.0 in c:\users\new\anaconda3\lib\site-packages (from librosa) (0.50.1)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\new\anaconda3\lib\site-packages (from librosa) (20.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\new\anaconda3\lib\site-packages (from librosa) (1.19.5)
# Collecting pooch>=1.0
#   Downloading pooch-1.5.2-py3-none-any.whl (57 kB)
# Requirement already satisfied: joblib>=0.14 in c:\users\new\anaconda3\lib\site-packages (from librosa) (0.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\new\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\new\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.0)
# Requirement already satisfied: llvmlite<0.34,>=0.33.0.dev0 in c:\users\new\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.33.0+1.g022ab0f)
# Requirement already satisfied: setuptools in c:\users\new\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (49.2.0.post20200714)
# Requirement already satisfied: six>=1.3 in c:\users\new\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\new\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: requests in c:\users\new\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.24.0)
# Requirement already satisfied: appdirs in c:\users\new\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: pycparser in c:\users\new\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\new\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\new\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\new\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\new\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (1.25.9)
# Building wheels for collected packages: resampy, audioread
#   Building wheel for resampy (setup.py): started
#   Building wheel for resampy (setup.py): finished with status 'done'
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320719 sha256=2e261cfa813055e8afdc2b29424655c49170e203834168672ea9813c2ca401e4
#   Stored in directory: c:\users\new\appdata\local\pip\cache\wheels\6f\d1\5d\f13da53b1dcbc2624ff548456c9ffb526c914f53c12c318bb4
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23143 sha256=4d6a75a28ea3cbc01b6b02c024d98648f5a14c6ffa85075d77840e66f2743819
#   Stored in directory: c:\users\new\appdata\local\pip\cache\wheels\49\5a\e4\df590783499a992a88de6c0898991d1167453a3196d0d1eeb7
# Successfully built resampy audioread
# Installing collected packages: soundfile, resampy, audioread, pooch, librosa
# Successfully installed audioread-2.1.9 librosa-0.8.1 pooch-1.5.2 resampy-0.2.2 soundfile-0.10.3.post1

# %%
import librosa 
from Metadata import getmetadata
a = getmetadata(r"C:\Users\new\Dropbox\My PC (LAPTOP-VOB8LHM1)\Downloads\reggae.00009.wav")

# %%
#Predictin using KNN 

d1 =np.array(a)
data1 = scaler.transform([d1])
genre_prediction = knn.predict(data1)
print(lookup_genre_name[genre_prediction[0]])
# Out:
# reggae

# %%
#Support Vector Machine

from sklearn.svm import SVC
clf = SVC(kernel = 'linear', C=10).fit(X_train_scaled, y_train)
clf.score(X_test_scaled, y_test)
# Out:
# 0.732

# %%
#Predicting using SVM

d1 =np.array(a)
data1 = scaler.transform([d1])
genre_prediction = clf.predict(data1)
print(lookup_genre_name[genre_prediction[0]])
# Out:
# reggae
